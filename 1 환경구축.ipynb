# %% [markdown]
# # Heading1
#
# ## Heading2
#
# ### Heading
#
#
# - List1
#     - List2
#         - List3
#
#
# 1. List1
#     1. list2
#         1. list3
#
#
# **HELLO**
#
#
# *HELLO*

# %%
from IPython.display import Image

# %%
Image(url = "https://t1.daumcdn.net/cfile/tistory/99BCFB485EDEDBAF25", width = 300, height = 300)
# Out:
# <img src="https://t1.daumcdn.net/cfile/tistory/99BCFB485EDEDBAF25" width="300" height="300"/>

# %%
from IPython.lib.display import YouTubeVideo

# %%
YouTubeVideo("D1PvIWdJ8xo",width = 300, height = 300)

# %% [markdown]
# ### 변수 a에 10을 대입하고 변수 b에 15를 대입한 후, 변수 c에 a+b를 할당해주세요.

# %%
a = 10
b = 15
c = a+b
c
# Out:
# 25

# %%
a, b = 10, 15
c = a+b
c
# Out:
# 25

# %% [markdown]
# ### 변수 str1과 str2에 hello python을 할당해주세요

# %%
str1, str2 = "hello python","hello python"
print(str1)
print(str2)
# Out:
# hello python
# hello python

# %%
str1 = str2 = "hello python"
print(str1, str2)
# Out:
# hello python hello python

# %%
"철수는 '6시에 집에 간다'고 했다."

# %%
print('He said,"she\'s gone"')
# Out:
# He said,"she's gone"

# %% [markdown]
# ## 인덱싱과 슬라이싱

# %%
sentence = "My name is Changhyun"

# %%
# 2개씩 띄어읽기
sentence[::2]
# Out:
# 'M aei hnyn'

# %%
sentence[4]
# Out:
# 'a'

# %%
sentence[3:7]
# Out:
# 'name'

# %%
sentence[-12:-10]
# Out:
# 'is'

# %% [markdown]
# - 날씨 정보를 받습니다.
# - 20220809sunny
# - 20220810cloudy
# - 20220811fog
#
# - 이 정보들을 년도,월,일,날씨 변수로 쪼개서  저장하고 싶습니다.
# - 어떤 날씨,정보가 오든지 연,월,일, 날씨를 변함없이 지칭하는 슬라이싱 코드를 짜봅시다.
#
# weather_info = "20220809sunny"

# %%
weather_info = "20220809sunny"

year = weather_info[:4]
month = weather_info[4:6]
day = weather_info[6:8]
weather = weather_info[8:]

print(year, month, day, weather)
# Out:
# 2022 08 09 sunny
